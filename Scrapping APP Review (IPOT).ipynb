# %% [markdown]
# # Scraping Data Review App IPOT

# %% [markdown]
# ## Instalasi Package

# %%
# !pip install google_play_scraper

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google_play_scraper import Sort, reviews

# %% [markdown]
# ## Scraping Data Review

# %%
result, continuation_token = reviews("com.indopremier.ipot",             # Alamat apps
                                     lang="id",                     # Bahasa Reviews , defaults : "en"
                                     country="id",                  # Negara Asal Reviewer defaults;  "us"
                                     sort=Sort.MOST_RELEVANT,       # Urutan Review yang diambil , 
                                     count=200)

# %% [markdown]
# ## Menyimpan Data Hasil Scrapping dalam Pandas Dataframe

# %%
Hasil_Scrapping = pd.DataFrame(result)
Hasil_Scrapping
# Out:
#                                               reviewId               userName  \
# 0    gp:AOqpTOFTWkRDdTHC8E-SNQTrDSyKNba1Rc0aRzjemji...        Dunia Investasi
# 1    gp:AOqpTOE5P1v5tfF4BlQfUqRI6J63QuJMhgV9VxEplY0...              ari yanti
# 2    gp:AOqpTOGDbktcIG7H3RQL9JkukNgeiedk6WUw-4krp3u...                  oo oo
# 3    gp:AOqpTOEWinVlXSge5C7m2Oz3DndBHp8AiVMLNn1vHgp...          Andhika Dwiki
# 4    gp:AOqpTOEpYsW7gG0ukWeapeKO7SC_D03aolrgJiI2Zue...                 Rianto
# ..                                                 ...                    ...
# 195  gp:AOqpTOH7i6UZzBBwGqfTC2DT_uNOcUsJ5S6nfn5zpoF...            WeeDee Team
# 196  gp:AOqpTOGVl_LIFAPw9ZDXK2ZysoI9fVHtgi2196ugKoE...             Ajm Terang
# 197  gp:AOqpTOGClebsU28L7XXmSKnL-Eu6Uwa6QaN09P_XIXs...  Tonny Holmes Manurung
# 198  gp:AOqpTOGFo7c8Xgrtp2WZ9M6o8vdx6UFGyLGb8M18xxk...             Mariinda s
# 199  gp:AOqpTOHrdnj5fmXRaNmFh0dvUn8tcDCtkvLDaVhOhuH...             HADY PRYTN
#
# ...

# %% [markdown]
# ## Menyimpan Data Hasil Scrapping dalam file CSV

# %%
Hasil_Scrapping.to_csv('Scrapping_IPOT.csv', index = False)
